# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosPella/AVANCE/blob/main/TareaEDA_CarlosPella.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Cargamos nuestra data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel("/content/drive/MyDrive/1 Bootcamp_Python_DSRP/6_SextaClase/TAREA EDA/Copia de bbdd_riesgo.xlsx")

data.head(3)
# Out:
#    ID  MORA60  ATRASO  TIPOCASA  EDAD FECHA_EMPLEO  TC  AHORRO  INGRESO  \
# 0   1       0     235  FAMILIAR    30   2007-06-01  93       5   3500.0
# 1   2       0      18  FAMILIAR    32   2005-02-01   9      12    900.0
# 2   3       0       0  FAMILIAR    26   2003-08-01   8       2   2400.0
#
#    LINEA_TC  SALDO_DEUDOR  SCORE  ABONO_PAGO DEPARTAMENTO  RIESGO_SBS  \
# 0      0.00          0.00    214           5         Lima           4
# 1   1824.67       1933.75    175          12  La Libertad           1
# 2   2797.38        188.29    187           0         Lima           0
#
#      EDUCACION
# 0  PROFESIONAL
# 1      TECNICO
# 2  PROFESIONAL

# %% [markdown]
# ##NIVEL BÁSICO

# %% [markdown]
# #¿Cuantas observaciones y variables tiene el conjunto de datos?

# %%
#FORMA 1
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            5000 non-null   int64
#  1   MORA60        5000 non-null   int64
#  2   ATRASO        5000 non-null   int64
#  3   TIPOCASA      5000 non-null   object
#  4   EDAD          5000 non-null   int64
#  5   FECHA_EMPLEO  5000 non-null   datetime64[ns]
#  6   TC            5000 non-null   int64
#  7   AHORRO        5000 non-null   int64
#  8   INGRESO       5000 non-null   float64
#  9   LINEA_TC      5000 non-null   float64
#  10  SALDO_DEUDOR  5000 non-null   float64
#  11  SCORE         5000 non-null   int64
#  12  ABONO_PAGO    5000 non-null   int64
#  13  DEPARTAMENTO  5000 non-null   object
#  14  RIESGO_SBS    5000 non-null   int64
#  15  EDUCACION     5000 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(9), object(3)
# memory usage: 625.1+ KB

# %%
#FORMA 2
data.shape
# Out:
# (5000, 16)

# %% [markdown]
# #¿Qué tipos de variables (numéricas, categóricas) se incluyen en el conjunto de datos y cómo se distribuyen?

# %%
data.dtypes
# Out:
# ID                       int64
# MORA60                   int64
# ATRASO                   int64
# TIPOCASA                object
# EDAD                     int64
# FECHA_EMPLEO    datetime64[ns]
# TC                       int64
# AHORRO                   int64
# INGRESO                float64
# LINEA_TC               float64
# SALDO_DEUDOR           float64
# SCORE                    int64
# ABONO_PAGO               int64
# DEPARTAMENTO            object
# RIESGO_SBS               int64
# EDUCACION               object
# dtype: object

# %% [markdown]
# #¿Cuál es la edad promedio de los clientes en el conjunto de datos?

# %%
prom= data['EDAD'].mean().round(0)
print(f"La edad promedio de los clientes en el conjunto de datos es", prom, "años")
# Out:
# La edad promedio de los clientes en el conjunto de datos es 36.0 años

# %% [markdown]
# #Proporcione las estadísticas descriptivas (media, mediana, desviación estándar, mínimo, máximo) para las variables numéricas.

# %%
data.describe(include=[np.number])
# Out:
#                 ID       MORA60      ATRASO         EDAD           TC  \
# count  5000.000000  5000.000000  5000.00000  5000.000000  5000.000000
# mean   2500.500000     0.700000     4.48080    36.429400    25.386000
# std    1443.520003     0.458303    13.94524     9.787225    32.014265
# min       1.000000     0.000000     0.00000    20.000000     0.000000
# 25%    1250.750000     0.000000     0.00000    29.000000     0.000000
# 50%    2500.500000     1.000000     0.00000    34.000000    12.000000
# 75%    3750.250000     1.000000     2.00000    42.000000    39.000000
# max    5000.000000     1.000000   245.00000    85.000000   130.000000
#
#             AHORRO       INGRESO       LINEA_TC  SALDO_DEUDOR        SCORE  \
# count  5000.000000   5000.000000    5000.000000   5000.000000  5000.000000
# mean     10.571000   4373.572006   10236.736330   5732.438204   196.762400
# std       3.396125   5393.520235   19853.871452  10869.692111    19.416316
# ...

# %% [markdown]
# #   Muestre estas medidas de tendencia central en un BoxPlot para cada variable mencionada.

# %%
#BOXPLOT
data1 = data

#MORA60
sns.boxplot(
    data=data1,
    x='MORA60',
)

plt.axvline(
    x=data1['MORA60'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()


#ATRASO
sns.boxplot(
    data=data1,
    x='ATRASO',
)

plt.axvline(
    x=data1['ATRASO'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()


#EDAD
sns.boxplot(
    data=data1,
    x='EDAD',
)

plt.axvline(
    x=data1['EDAD'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()


#TC
sns.boxplot(
    data=data1,
    x='TC',
)

plt.axvline(
    x=data1['TC'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()


#AHORRO
sns.boxplot(
    data=data1,
    x='AHORRO',
)

plt.axvline(
    x=data1['AHORRO'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

#INGRESO
sns.boxplot(
    data=data1,
    x='INGRESO',
)

plt.axvline(
    x=data1['INGRESO'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

#LINEA_TC
sns.boxplot(
    data=data1,
    x='LINEA_TC',
)

plt.axvline(
    x=data1['LINEA_TC'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

#SALDO_DEUDOR
sns.boxplot(
    data=data1,
    x='SALDO_DEUDOR',
)

plt.axvline(
    x=data1['SALDO_DEUDOR'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

#SCORE
sns.boxplot(
    data=data1,
    x='SCORE',
)

plt.axvline(
    x=data1['SCORE'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

#ABONO_PAGO
sns.boxplot(
    data=data1,
    x='ABONO_PAGO',
)

plt.axvline(
    x=data1['ABONO_PAGO'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

#RIESGO_SBS
sns.boxplot(
    data=data1,
    x='RIESGO_SBS',
)

plt.axvline(
    x=data1['RIESGO_SBS'].mean(),
    color='red',
    linestyle='dashed',
    linewidth=2
)
plt.show()

# %% [markdown]
# #Proporcione estadísticas para las variables categóricas (texto).

# %%
data.describe(include=object)
# Out:
#         TIPOCASA DEPARTAMENTO    EDUCACION
# count       5000         5000         5000
# unique         4           25            5
# top     FAMILIAR         Lima  PROFESIONAL
# freq        3471         2948         2666

# %% [markdown]
# ##NIVEL INTERMEDIO

# %% [markdown]
# #¿Hay alguna variable con valores faltantes en el conjunto de datos?

# %%
#PRIMERO REVISAMOS LA PROPORCIÓN
df = data.isnull().melt()

sns.displot(data=df,
            y='variable',
            hue='value',
            multiple='fill',
            aspect=2)
plt.show()

# %%
#COMO NO NOS INDICA NADA, BUSCAMOS NÚMERICOS
data.isnull().sum()
# Out:
# ID              0
# MORA60          0
# ATRASO          0
# TIPOCASA        0
# EDAD            0
# FECHA_EMPLEO    0
# TC              0
# AHORRO          0
# INGRESO         0
# LINEA_TC        0
# SALDO_DEUDOR    0
# SCORE           0
# ABONO_PAGO      0
# DEPARTAMENTO    0
# RIESGO_SBS      0
# EDUCACION       0
# dtype: int64

# %% [markdown]
# #Genere un gráfico de barras para todas las variables numéricas.

# %%
#MORA 60

sns.catplot(
    data=data1,
    x='MORA60',
    kind='count'
)
plt.show()

#ATRASO
sns.catplot(
    data=data1,
    x='ATRASO',
    kind='count'
)
plt.show()

#EDAD
sns.catplot(
    data=data1,
    x='EDAD',
    kind='count'
)
plt.show()

#TC
sns.catplot(
    data=data1,
    x='TC',
    kind='count'
)
plt.show()

#AHORRO
sns.catplot(
    data=data1,
    x='AHORRO',
    kind='count'
)
plt.show()

#INGRESO
sns.catplot(
    data=data1,
    x='INGRESO',
    kind='count'
)
plt.show()

#LINEA_TC
sns.catplot(
    data=data1,
    x='LINEA_TC',
    kind='count'
)
plt.show()

#SALDO_DEUDOR
sns.catplot(
    data=data1,
    x='SALDO_DEUDOR',
    kind='count'
)
plt.show()

#SCORE
sns.catplot(
    data=data1,
    x='SCORE',
    kind='count'
)
plt.show()

#ABONO_PAGO
sns.catplot(
    data=data1,
    x='ABONO_PAGO',
    kind='count'
)
plt.show()

#RIESGO_SBS
sns.catplot(
    data=data1,
    x='RIESGO_SBS',
    kind='count'
)
plt.show()

# %% [markdown]
# # Genere un gráfico de barras para mostrar la frecuencia de las variables categoricas.

# %%
#VARIABLES CATEGORICAS
d1 = data['TIPOCASA'].value_counts(sort=True).reset_index(name='count')
d2 = data['DEPARTAMENTO'].value_counts(sort=True).reset_index(name='count')
d3 = data['EDUCACION'].value_counts(sort=True).reset_index(name='count')


sns.barplot(data=d1,
            x='index',
            y='count')
plt.show()

sns.barplot(data=d2,
            x='index',
            y='count')
plt.xticks(rotation=90)
plt.show()

sns.barplot(data=d3,
            x='index',
            y='count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #Grafique la correlación entre INGRESO y el monto de la línea de crédito de tarjeta de crédito.

# %%
correlacion_numpy = np.corrcoef(data['INGRESO'], data['LINEA_TC'])
print(correlacion_numpy)
# Out:
# [[1.         0.51830831]
#  [0.51830831 1.        ]]

# %%
COR = pd.crosstab(data['INGRESO'],data['LINEA_TC'])
sns.heatmap(COR)
plt.show()

# %% [markdown]
# #Realice un diagrama de dispersión entre la EDAD y el RIESGO_SBS.

# %%
sns.scatterplot(x='EDAD', y='RIESGO_SBS', data=data1)

plt.xlabel('Edad')
plt.ylabel('Riesgo SBS')
plt.title('Diagrama de dispersión entre EDAD y RIESGO_SBS')

plt.show()

# %% [markdown]
# # Realice un headmap para TIPOCASA y EDUCACION.

# %%
COR = pd.crosstab(data['TIPOCASA'],data['EDUCACION'])
sns.heatmap(COR)
plt.show()

# %% [markdown]
# #Realice un headmap para EDAD y RIESGO_SBS.

# %%
COR = pd.crosstab(data['EDAD'],data['RIESGO_SBS'])
sns.heatmap(COR)
plt.show()

# %% [markdown]
# ##NIVEL AVANZADO

# %% [markdown]
# #¿Qué porcentaje de clientes ha tenido una morosidad mayor a 60 días (`MORA60`) después de la aprobación del crédito?

# %%
#PORCENTAJE
moro = data[data['ATRASO'] > 60]

porcen = (len(moro) / len(data)) * 100

print(f"Porcentaje de clientes con morosidad mayor a 60 días: {porcen:.2f}%")


#CONTEO
cont = data[data['ATRASO'] > 60]

cantidad_morosos = len(cont)
cantidad_morosos
# Out:
# Porcentaje de clientes con morosidad mayor a 60 días: 0.42%
# 21

# %% [markdown]
# #Investigue si existe alguna relación entre el nivel educativo y la incidencia de morosidad mayor a 60 días. ¿Cómo podría visualizar esta relación?

# %%
#CON MAPA DE CALOR
tab = pd.crosstab(data['MORA60'],data['EDUCACION'])

sns.heatmap(tab)
plt.show()

# %%
#GRAFICO DE BARRAS
cont = data[data['ATRASO'] > 60]


cant = cont['EDUCACION'].value_counts()


sns.barplot(x=cant.index, y=cant.values)
plt.xlabel('Nivel Educativo')
plt.ylabel('Número de Morosos')
plt.title('Relación entre Nivel Educativo y Morosidad ')
plt.show()
